# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#      --------------------------------------- 0.0/11.3 MB 279.3 kB/s eta 0:00:41
#      --------------------------------------- 0.0/11.3 MB 279.3 kB/s eta 0:00:41
#      --------------------------------------- 0.1/11.3 MB 467.6 kB/s eta 0:00:25
#      --------------------------------------- 0.1/11.3 MB 467.6 kB/s eta 0:00:25
#      --------------------------------------- 0.1/11.3 MB 405.9 kB/s eta 0:00:28
#       -------------------------------------- 0.2/11.3 MB 597.3 kB/s eta 0:00:19
#       -------------------------------------- 0.3/11.3 MB 628.5 kB/s eta 0:00:18
# ...

# %%
import pandas as pd

# %%
data =[1,2,3]
df = pd.DataFrame(data)
print(df)
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
pd.read_csv{"insurance_data.csv"}
# Out:
#   Cell In[9], line 1
#     pd.read_csv{"insurance_data.csv"}
#                ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
df = pd.read_csv("insurance_data.csv")
print(df)
# Out:
#    Policy No     Name  Age  Premium Amount Policy Type    Status
# 0        101     Arun   30            5000        Life    Active
# 1        102    Priya   28            4500      Health    Active
# 2        103     Ravi   40            7000        Life  Inactive
# 3        104    Meena   35            6000     Vehicle    Active
# 4        105  Karthik   50            8000      Health  Inactive
