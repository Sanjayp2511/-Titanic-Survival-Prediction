# %%
import pandas as pd

# %%
data =[1,2,3]
df = pd.DataFrame(data)
print(df)
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
pd.read_csv{"insurance_data.csv"}
# Out:
#   Cell In[9], line 1
#     pd.read_csv{"insurance_data.csv"}
#                ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
np.repeat(3,4)
# Out:
# array([3, 3, 3, 3])

# %%
np.repeat(a = df,repeats = 2,axis = 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 np.repeat(a = df,repeats = 2,axis = 0)
#
# NameError: name 'df' is not defined

# %%
pd.read_csv(filepath_or_buffer = "insurance_data.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 pd.read_csv(filepath_or_buffer = "insurance_data.csv")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
pd.read_csv( filepath_or_buffer = "insurance_data-checkpoint.csv")
# Out:
#    Policy No     Name  Age  Premium Amount Policy Type    Status
# 0        101     Arun   30            5000        Life    Active
# 1        102    Priya   28            4500      Health    Active
# 2        103     Ravi   40            7000        Life  Inactive
# 3        104    Meena   35            6000     Vehicle    Active
# 4        105  Karthik   50            8000      Health  Inactive

# %%
ins_data =pd.read_csv( filepath_or_buffer = "insurance_data-checkpoint.csv")

# %%
ins_data
# Out:
#    Policy No     Name  Age  Premium Amount Policy Type    Status
# 0        101     Arun   30            5000        Life    Active
# 1        102    Priya   28            4500      Health    Active
# 2        103     Ravi   40            7000        Life  Inactive
# 3        104    Meena   35            6000     Vehicle    Active
# 4        105  Karthik   50            8000      Health  Inactive

# %%
import numpy as np

# %%
np.repeat(a = ins_data,repeats=1,axis=1)
# Out:
# array([[101, 'Arun', 30, 5000, 'Life', 'Active'],
#        [102, 'Priya', 28, 4500, 'Health', 'Active'],
#        [103, 'Ravi', 40, 7000, 'Life', 'Inactive'],
#        [104, 'Meena', 35, 6000, 'Vehicle', 'Active'],
#        [105, 'Karthik', 50, 8000, 'Health', 'Inactive']], dtype=object)

# %%
ins_data_update = pd.DataFrame(data=np.repeat(a = ins_data,repeats=2,axis=0))
ins_data_update
# Out:
#      0        1   2     3        4         5
# 0  101     Arun  30  5000     Life    Active
# 1  101     Arun  30  5000     Life    Active
# 2  102    Priya  28  4500   Health    Active
# 3  102    Priya  28  4500   Health    Active
# 4  103     Ravi  40  7000     Life  Inactive
# 5  103     Ravi  40  7000     Life  Inactive
# 6  104    Meena  35  6000  Vehicle    Active
# 7  104    Meena  35  6000  Vehicle    Active
# 8  105  Karthik  50  8000   Health  Inactive
# 9  105  Karthik  50  8000   Health  Inactive

# %%
from matplotlib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 from matplotlib import pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#      ---------------------------------------- 0.1/8.1 MB 812.7 kB/s eta 0:00:10
#      ---------------------------------------- 0.1/8.1 MB 871.5 kB/s eta 0:00:10
#       --------------------------------------- 0.1/8.1 MB 774.0 kB/s eta 0:00:11
#      - -------------------------------------- 0.2/8.1 MB 981.9 kB/s eta 0:00:09
#      - -------------------------------------- 0.3/8.1 MB 1.0 MB/s eta 0:00:08
#      - -------------------------------------- 0.3/8.1 MB 930.9 kB/s eta 0:00:09
#      - -------------------------------------- 0.3/8.1 MB 930.9 kB/s eta 0:00:09
#      - -------------------------------------- 0.3/8.1 MB 759.5 kB/s eta 0:00:11
#      - -------------------------------------- 0.4/8.1 MB 794.9 kB/s eta 0:00:10
#      - -------------------------------------- 0.4/8.1 MB 764.2 kB/s eta 0:00:11
# ...

# %%
 from matplotlib import pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.hist(x=ins_data.Age)
# Out:
# (array([2., 0., 0., 1., 0., 1., 0., 0., 0., 1.]),
#  array([28. , 30.2, 32.4, 34.6, 36.8, 39. , 41.2, 43.4, 45.6, 47.8, 50. ]),
#  <BarContainer object of 10 artists>)

# %%
print(ins_data.columns)
# Out:
# Index(['Policy No', 'Name', 'Age', 'Premium Amount', 'Policy Type', 'Status'], dtype='object')

# %%
ins_data
# Out:
#    Policy No     Name  Age  Premium Amount Policy Type    Status
# 0        101     Arun   30            5000        Life    Active
# 1        102    Priya   28            4500      Health    Active
# 2        103     Ravi   40            7000        Life  Inactive
# 3        104    Meena   35            6000     Vehicle    Active
# 4        105  Karthik   50            8000      Health  Inactive

# %%
import seaborn as sb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 import seaborn as sb
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
pip install seaborn
# Out:
# ...
#      ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#      - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#      - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#      - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#      - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#      -- ----------------------------------- 20.5/294.9 kB 46.8 kB/s eta 0:00:06
#      -- ----------------------------------- 20.5/294.9 kB 46.8 kB/s eta 0:00:06
#      -- ----------------------------------- 20.5/294.9 kB 46.8 kB/s eta 0:00:06
#      -- ----------------------------------- 20.5/294.9 kB 46.8 kB/s eta 0:00:06
#      ----- -------------------------------- 41.0/294.9 kB 75.7 kB/s eta 0:00:04
#      ----- -------------------------------- 41.0/294.9 kB 75.7 kB/s eta 0:00:04
#      ------- ------------------------------ 61.4/294.9 kB 99.4 kB/s eta 0:00:03
# ...

# %%
import seaborn as sb

# %%
ins.data['Age'].plot(kind='bar')plt.show()
# Out:
#   Cell In[47], line 1
#     ins.data['Age'].plot(kind='bar')plt.show()
#                                     ^
# SyntaxError: invalid syntax

# %%
import plotly as pt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 import plotly as pt
#
# ModuleNotFoundError: No module named 'plotly'

# %% [raw]
# pip install plotly

# %%
import sklearn as sk
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 import sklearn as sk
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
pip install sklearn
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [15 lines of output]
#   The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#   rather than 'sklearn' for pip commands.
#
#   Here is how to fix this error in the main use cases:
#   - use 'pip install scikit-learn' rather than 'pip install sklearn'
#   - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#     (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#   - if the 'sklearn' package is used by one of your dependencies,
#     it would be great if you take some time to track which package uses
#     'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#   - as a last resort, set the environment variable
# ...
