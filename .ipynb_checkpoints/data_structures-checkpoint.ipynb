# %% [markdown]
# ## python data structures

# %% [markdown]
# list
# tuple
# dictionary
# sets

# %%
mark = ()
mark
# Out:
# ()

# %%
type(mark)
# Out:
# tuple

# %%
lst=['apple','orange','lemon',92,76]
lst
# Out:
# ['apple', 'orange', 'lemon', 92, 76]

# %%
len(lst)
# Out:
# 5

# %%
print(lst)
# Out:
# ['apple', 'orange', 'lemon', 92, 76]

# %%
lst[-4:0]
# Out:
# []

# %%
a={'A','B',3,43,433,43,'C','A'}
a
# Out:
# {3, 43, 433, 'A', 'B', 'C'}

# %%
type(a)
# Out:
# set

# %%
len(a)
# Out:
# 6

# %%
lst[2]='grape'
lst
# Out:
# ['apple', 'orange', 'grape', 92, 76]

# %%
tup=32,54,76,45,'sanjay','arun','siva'
tup
# Out:
# (32, 54, 76, 45, 'sanjay', 'arun', 'siva')

# %%
tup[0:5]
# Out:
# (32, 54, 76, 45, 'sanjay')

# %%
marks={'Tamil':98,'English':87,'Maths':76,'Sciece':90}
marks
# Out:
# {'Tamil': 98, 'English': 87, 'Maths': 76, 'Sciece': 90}

# %%
import pandas as pd

# %%
type(marks)
# Out:
# dict

# %%
stud_mark={'names':['arun','alagu','pandi','esakki'],'maths':(99,88,77,66),'science':(98,87,76,65,)}
stud_mark
# Out:
# {'names': ['arun', 'alagu', 'pandi', 'esakki'],
#  'maths': (99, 88, 77, 66),
#  'science': (98, 87, 76, 65)}

# %%
pd.DataFrame(data=stud_mark)
# Out:
#     names  maths  science
# 0    arun     99       98
# 1   alagu     88       87
# 2   pandi     77       76
# 3  esakki     66       65
